# %%
import pandas as pd

# %%
df = pd.read_csv("Loan_Prediction.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df = df.drop('Loan_ID', axis=1)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
df.columns[df.isna().any()]
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Self_Employed', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
dff = df.copy()

# %%
dff.isna()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0     False    False       False      False          False            False
# 1     False    False       False      False          False            False
# 2     False    False       False      False          False            False
# 3     False    False       False      False          False            False
# 4     False    False       False      False          False            False
# ..      ...      ...         ...        ...            ...              ...
# 609   False    False       False      False          False            False
# 610   False    False       False      False          False            False
# 611   False    False       False      False          False            False
# 612   False    False       False      False          False            False
# 613   False    False       False      False          False            False
#
# ...

# %%
dff.dropna()
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %% [markdown]
# ### drop nan values

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (480, 12)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
# 5   Male     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# ...

# %% [markdown]
# ### Assigning dummy values

# %%
df['Credit_History'].unique()
# Out:
# array([1., 0.])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le1 = LabelEncoder()
le2 = LabelEncoder()
le3 = LabelEncoder()
le4 = LabelEncoder()
le5 = LabelEncoder()
le6 = LabelEncoder()
le7 = LabelEncoder()
le8 = LabelEncoder()

# %%
df['Gender'] = le1.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#    Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1       1     Yes          1      Graduate            No             4583
# 2       1     Yes          0      Graduate           Yes             3000
# 3       1     Yes          0  Not Graduate            No             2583
# 4       1      No          0      Graduate            No             6000
# 5       1     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# ...

# %%
df['Gender'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Married'] = le2.fit_transform(df['Married']) 
df['Education'] = le3.fit_transform(df['Education']) 
df['Self_Employed'] = le4.fit_transform(df['Self_Employed']) 
df['Credit_History'] = le5.fit_transform(df['Credit_History']) 
df['Property_Area'] = le6.fit_transform(df['Property_Area']) 
df['Loan_Status'] = le7.fit_transform(df['Loan_Status']) 
df['Dependents'] = le8.fit_transform(df['Dependents'])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
# 5       1        1           2          0              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0               1
# 2                0.0        66.0             360.0               1
# 3             2358.0       120.0             360.0               1
# 4                0.0       141.0             360.0               1
# 5             4196.0       267.0             360.0               1
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              2            1
# ...

# %%
df.Loan_Amount_Term.unique()
# Out:
# array([360., 120., 180.,  60., 300., 480., 240.,  36.,  84.])

# %%
X = df.drop(['Loan_Status','Dependents'], axis=1)
y = df.Loan_Status

# %%
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler()
#scaled = sc.fit_transform([[X[['Loan_Amount_Term']], X[['LoanAmount']], X[['ApplicantIncome']],X[['CoapplicantIncome']]]])
X['Loan_Amount_Term']=sc.fit_transform(X[['Loan_Amount_Term']])
X['LoanAmount']=sc.fit_transform(X[['LoanAmount']])
X['ApplicantIncome']=sc.fit_transform(X[['ApplicantIncome']])
X['CoapplicantIncome']=sc.fit_transform(X[['CoapplicantIncome']])
y=sc.fit_transform(df[['Loan_Status']])
X['Gender']=sc.fit_transform(X[['Gender']])
X['Credit_History']=sc.fit_transform(X[['Credit_History']])
X['Property_Area']=sc.fit_transform(X[['Property_Area']])
X['Married']=sc.fit_transform(X[['Married']])
#X['Dependents']=sc.fit_transform(X[['Dependents']])
X['Education']=sc.fit_transform(X[['Education']])
X['Self_Employed']=sc.fit_transform(X[['Self_Employed']])

# %%
X.head()
# Out:
#    Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 1     1.0      1.0        0.0            0.0         0.054830
# 2     1.0      1.0        0.0            1.0         0.035250
# 3     1.0      1.0        1.0            0.0         0.030093
# 4     1.0      0.0        0.0            0.0         0.072356
# 5     1.0      1.0        0.0            1.0         0.065145
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1           0.044567    0.201354           0.72973             1.0
# 2           0.000000    0.096447           0.72973             1.0
# 3           0.069687    0.187817           0.72973             1.0
# 4           0.000000    0.223350           0.72973             1.0
# 5           0.124006    0.436548           0.72973             1.0
#
#    Property_Area
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# 5            1.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, test_size=0.3)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train.shape
# Out:
# (336, 10)

# %%
y_train.shape
# Out:
# (336, 1)

# %%
X_train.head()
# Out:
#      Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 560     1.0      1.0        1.0            0.0         0.043599
# 75      1.0      0.0        0.0            0.0         0.044527
# 145     0.0      1.0        0.0            0.0         0.026964
# 397     1.0      1.0        0.0            0.0         0.035659
# 319     1.0      1.0        0.0            1.0         0.121831
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 560           0.007152    0.167513           0.72973             1.0
# 75            0.000000    0.175973           1.00000             1.0
# 145           0.132577    0.153976           0.72973             1.0
# 397           0.043118    0.145516           0.72973             1.0
# 319           0.000000    0.247039           0.72973             1.0
#
#      Property_Area
# 560            0.5
# 75             1.0
# 145            0.5
# 397            1.0
# 319            0.0

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train,y_train)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [0.1,1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10,20]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [0.1,1,5,10]
        }
    },
    
}
scores = []
best_estimators = {}

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train,y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators['model'] = clf.best_estimator_
df2 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df2
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
final_model = svm.SVC(C='0.1',kernel='linear')

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.34      0.51        44
#          1.0       0.78      1.00      0.87       100
#
#     accuracy                           0.80       144
#    macro avg       0.89      0.67      0.69       144
# weighted avg       0.84      0.80      0.76       144

# %%
model.score(X_test,y_test)
# Out:
# 0.7986111111111112

# %%
modell = LogisticRegression(C=1)
modell.fit(X_train,y_train)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_predd = modell.predict(X_test)

# %%
print(classification_report(y_test,y_predd))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.34      0.51        44
#          1.0       0.78      1.00      0.87       100
#
#     accuracy                           0.80       144
#    macro avg       0.89      0.67      0.69       144
# weighted avg       0.84      0.80      0.76       144

# %%
modell.score(X_test,y_test)
# Out:
# 0.7986111111111112
